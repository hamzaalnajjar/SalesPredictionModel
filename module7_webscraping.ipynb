# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzaalnajjar/SalesPredictionModel/blob/main/module7_webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

#define url
url = "https://books.toscrape.com/catalogue/page-1.html"
base_url = "https://books.toscrape.com/catalogue/"

#send + request url
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

#finds book listing
books = soup.find_all('article', class_='product_pod')

#extracting chips
book_data = []

for book in books:
    title = book.h3.a['title']
    relative_link = book.h3.a['href']
    full_link = base_url + relative_link
    price = book.find('p', class_='price_color').text.strip()
    availability = book.find('p', class_='instock availability').text.strip()

    book_data.append({
        'title': title,
        'link': full_link,
        'price': price,
        'availability': availability
    })

#convert to df
df = pd.DataFrame(book_data)

#saving csv
df.to_csv('scraped_books.csv', index=False)

#shows result
df.head()
# Out:
#                                    title  \
# 0                   A Light in the Attic
# 1                     Tipping the Velvet
# 2                             Soumission
# 3                          Sharp Objects
# 4  Sapiens: A Brief History of Humankind
#
#                                                 link   price availability
# 0  https://books.toscrape.com/catalogue/a-light-i...  £51.77     In stock
# 1  https://books.toscrape.com/catalogue/tipping-t...  £53.74     In stock
# 2  https://books.toscrape.com/catalogue/soumissio...  £50.10     In stock
# 3  https://books.toscrape.com/catalogue/sharp-obj...  £47.82     In stock
# 4  https://books.toscrape.com/catalogue/sapiens-a...  £54.23     In stock
